# %% [markdown]
# <a href="https://colab.research.google.com/github/afpalmasan/DataViz-MatPlotlib-Seaborn/blob/maester/DataViz_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## SEABORN
#
# ---

# %% [markdown]
# SET : Set es un método de Seaborn que permite configurar el estilo, fuente y color de las gráficas.

# %%
import seaborn as sns # Importar libreria de forma estandar como sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=['A','b','C'], y=[1,3,2])
plt.show()

# %% [markdown]
# ## Configurar fuentes y estilos
# Configura el estilo, la paleta de colores, la fuente y el tamaño de la fuente de la gráfica.

# %%
sns.set(style='dark', palette='Spectral',)
sns.barplot(x=['A','b','C'], y=[1,3,2])
plt.show()
